# %%
import json, requests, pandas as pd
# country = input()
# month = input()

url = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/Belgium.csv"
file = pd.read_csv(url, error_bad_lines=False)

file
# Out:
# C:\Users\thibo\AppData\Local\Temp\ipykernel_4132\1332294066.py:6: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   file = pd.read_csv(url, error_bad_lines=False)
#     location        date                                            vaccine  \
# 0    Belgium  2020-12-28                                    Pfizer/BioNTech
# 1    Belgium  2020-12-29                                    Pfizer/BioNTech
# 2    Belgium  2020-12-30                                    Pfizer/BioNTech
# 3    Belgium  2020-12-31                                    Pfizer/BioNTech
# 4    Belgium  2021-01-01                                    Pfizer/BioNTech
# ..       ...         ...                                                ...
# 452  Belgium  2022-03-25  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 453  Belgium  2022-03-26  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# ...
